# %% [markdown]
# <a href="https://colab.research.google.com/github/polnatikrishna123/Fmml-lab/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 02:29:10--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   221MB/s    in 0.3s
#
# 2024-03-31 02:29:12 (221 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 18293   0805.2440v1  This paper describes application of informatio...    cs
# 39139   1404.3290v1  Block-based motion estimation (ME) and compens...    cs
# 5521    1205.4217v2  The question of the optimality of Thompson Sam...  stat
# 7703   1802.09246v2  Variable selection is central to high-dimensio...  stat
# 22332  1602.03670v2  Extracting the underlying low-dimensional spac...  stat
# ...             ...                                                ...   ...
# 23016  1802.00243v1  We study a logistic model-based active learnin...  stat
# 5427    1210.4792v2  We propose a general matrix-valued multiple ke...  stat
# 7208   1711.01204v2  Neural samplers such as variational autoencode...  stat
# 38934   1402.3657v1  Driver fatigue is one of the important factors...    cs
# 13727   1312.4149v1  Recently, with the rapid development of techno...    cs
#
#                                                    title  year  \
# 18293  Analysis of hydrocyclone performance based on ...  2008
# 39139  Motion-Compensated Coding and Frame-Rate Up-Co...  2014
# 5521   Thompson Sampling: An Asymptotically Optimal F...  2012
# 7703   Scalable kernel-based variable selection with ...  2018
# 22332  Online Low-Rank Subspace Learning from Incompl...  2016
# ...                                                  ...   ...
# 23016  Greedy Active Learning Algorithm for Logistic ...  2018
# 5427   Scalable Matrix-valued Kernel Learning for Hig...  2012
# 7208                  Metrics for Deep Generative Models  2017
# 38934  A Narrative Vehicle Protection Representation ...  2014
# 13727       Autonomous Quantum Perceptron Neural Network  2013
#
#                                                 keywords
# 18293  [describes, application, information, granulat...
# 39139  [estimation, compensation, techniques, process...
# 5521   [optimality, stochastic, positively, bernoulli...
# 7703   [selection, dimensional, algorithms, developed...
# 22332  [extracting, underlying, dimensional, dimensio...
# ...                                                  ...
# 23016  [procedure, classification, selection, sequent...
# 5427   [framework, dimensional, nonlinear, multivaria...
# 7208   [variational, autoencoders, generative, advers...
# 38934  [important, accidents, increasing, diminished,...
# 13727  [development, technology, applications, comput...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 18293    [describes, application, information, granulat...
# 39139    [estimation, compensation, techniques, process...
# 5521     [optimality, stochastic, positively, bernoulli...
# 7703     [selection, dimensional, algorithms, developed...
# 22332    [extracting, underlying, dimensional, dimensio...
#                                ...
# 39221    [metastasis, therefore, statistical, resulting...
# 1165     [convolution, interpretable, representation, r...
# 12690    [classifiers, including, vulnerable, adversari...
# 8451     [segmentation, association, partition, difficu...
# 29982    [classification, investigating, synthesized, g...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8828 words.
# Out of those 4603 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="61fc4d4f-0dcc-42c0-8153-6bd5eec04c12" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("61fc4d4f-0dcc-42c0-8153-6bd5eec04c12")) {                    Plotly.newPlot(                        "61fc4d4f-0dcc-42c0-8153-6bd5eec04c12",                        [{"x":["simplicity","describes","performance","balancing","granulation","information","stability","combining","iteration","algorithm","inference","guaranteed","validation","organizing","application","conversion","processing","reference","compensated","respectively","compression","affecting","therefore","estimations","constructions","techniques","separable","procedures","dependency","estimation","comparing","applications","compensation","interpolation","experimental","prediction","predicted","diversity","examination","theoretic","foundation","beneficial","specifications","autocorrelation","specifically","calculated","considers","algorithms","theoretically","translational","available","comprehensive","cumulative","literature","bernoulli","accompanied","asymptotically","experiments","positively","comparison","providing","stochastic","asymptotic","numerical","optimality","reproducing","interaction","selection","involving","assumption","dimension","advantage","computation","established","predictor","different","computational","properties","regression","thresholding","dimensional","modification","simulated","including","theoretical","desirable","guarantee","effectiveness","conditions","functions","computing","developed","supported","currently","sophisticated","presented","counterparts","principles","incomplete","complexity","observations","variational","simultaneously","dictionary","recursively","underlying","sequentially","exploiting","outperforms","extracting","streaming","hierarchical","objective","commonplace","conducted","explicitly","envisaged","approximate","framework","parameters","obtaining","illustrate","arbitrary","processes","practical","estimator","introduction","demonstrate","clustering","likelihood","blockwise","probabilistic","constructing","classification","constructed","estimating","components","generating","estimators","justification","derivation","criterion","consistent","surrogate","imbalance","sensitive","maximizing","consistently","detection","suspicious","perception","minimizing","perspective","monitoring","supervised","benchmarked","important","conclusion","applicability","equivalent","extensive","potential","competitive","occurring","limitation","representing","foreground","occlusion","synthetic","frequently","distinctive","generation","especially","background","accurately","carefully","interactions","conventional","boundaries","reflecting","variations","characteristics","deblurring","assessment","inspection","databases","combinations","identification","determine","component","potentially","consisting","vulnerability","conceptually","automation","automated","configuration","penetration","strategies","weaknesses"],"y":[29,83,869,17,2,687,28,91,47,800,183,34,69,13,250,11,308,56,2,84,48,12,161,7,9,378,8,34,56,223,69,419,4,21,372,227,37,48,10,42,15,15,11,3,177,31,42,591,33,2,329,63,15,124,5,3,16,637,5,130,97,146,20,80,28,5,91,179,41,50,71,97,155,46,13,737,297,220,133,16,171,20,66,248,163,34,34,216,131,202,138,182,17,69,16,178,21,44,31,237,83,57,121,50,15,110,24,66,260,69,8,101,184,1,94,76,1,111,567,250,40,78,78,99,138,38,23,558,124,71,1,162,44,512,60,74,97,93,22,5,14,46,78,14,11,64,33,36,373,3,30,45,72,31,198,6,378,15,46,52,169,137,137,17,30,71,29,28,124,35,6,164,135,80,70,38,69,98,36,5,102,83,6,48,7,49,40,109,80,92,47,52,3,10,13,101,31,3,91,9],"type":"bar"},{"x":["simplicity","describes","performance","balancing","granulation","information","stability","comb ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4603,), (4603, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.81

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.4545454545454546);'>Architectural</span> <span style='background-color:rgba(0, 255, 0, 0.40000000000000013);'>Considerations</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Conversational</span> <span style=''>Systems</span> <span style=''>The</span> <span style=''>VerbmobilINTARC</span> <span style='background-color:rgba(0, 255, 0, 0.40740740740740755);'>Experience</span> <br/><br/><span style=''>The</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.509090909090909);'>describes</span> <span style=''>the</span> <span style=''>speech</span> <span style=''>to</span> <span style=''>speech</span> <span style='background-color:rgba(0, 255, 0, 0.8181818181818182);'>translation</span> <span style=''>system</span> <span style=''>INTARC</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developed</span> <span style=''>during</span> <span style=''>the</span> <span style=''>first</span> <span style=''>phase</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Verbmobil</span> <span style=''>project</span> <span style=''>The</span> <span style=''>general</span> <span style=''>design</span> <span style=''>goals</span> <span style=''>of</span> <span style=''>the</span> <span style=''>INTARC</span> <span style=''>system</span> <span style='background-color:rgba(0, 255, 0, 0.5359477124183007);'>architecture</span> <span style=''>were</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>synchronous</span> <span style='background-color:rgba(0, 255, 0, 0.4392523364485982);'>processing</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>incrementality</span> <span style=''>and</span> <span style=''>interactivity</span> <span style=''>as</span> <span style=''>a</span> <span style=''>means</span> <span style=''>to</span> <span style=''>achieve</span> <span style=''>a</span> <span style=''>higher</span> <span style=''>degree</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>robustness</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scalability</span> <span style=''>Interactivity</span> <span style=''>means</span> <span style=''>that</span> <span style=''>in</span> <span style=''>addition</span> <span style=''>to</span> <span style=''>the</span> <span style=''>bottom</span> <span style=''>up</span> <span style=''>(in</span> <span style=''>terms</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.4392523364485982);'>processing</span> <span style=''>levels)</span> <span style=''>data</span> <span style=''>flow</span> <span style=''>the</span> <span style=''>ability</span> <span style=''>to</span> <span style=''>process</span> <span style=''>top</span> <span style=''>down</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restrictions</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considering</span> <span style=''>the</span> <span style=''>same</span> <span style=''>signal</span> <span style=''>segment</span> <span style=''>for</span> <span style=''>all</span> <span style='background-color:rgba(0, 255, 0, 0.4392523364485982);'>processing</span> <span style=''>levels</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construction</span> <span style=''>of</span> <span style=''>INTARC</span> <span style=''>20</span> <span style=''>which</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454546);'>operational</span> <span style=''>since</span> <span style=''>fall</span> <span style=''>1996</span> <span style=''>followed</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.372093023255814);'>engineering</span> <span style=''>approach</span> <span style='background-color:rgba(0, 255, 0,  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Gaussian</span> <span style=''>Process</span> <span style=''>Kernels</span> <span style=''>for</span> <span style=''>Pattern</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Discovery</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Extrapolation</span> <br/><br/><span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>are</span> <span style=''>rich</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>which</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>approach</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>smoothing</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpolation</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>simple</span> <span style=''>closed</span> <span style=''>form</span> <span style=''>kernels</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>with</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>to</span> <span style=''>discover</span> <span style=''>patterns</span> <span style=''>and</span> <span style=''>enable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extrapolation</span> <span style=''>These</span> <span style=''>kernels</span> <span style=''>are</span> <span style=''>derived</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>modelling</span> <span style=''>a</span> <span style=''>spectral</span> <span style=''>density</span> <span style=''>the</span> <span style=''>Fourier</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transform</span> <span style=''>of</span> <span style=''>a</span> <span style=''>kernel</span> <span style=''>with</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style=''>mixture</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>kernels</span> <span style=''>support</span> <span style=''>a</span> <span style=''>broad</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stationary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariances</span> <span style=''>but</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>remains</span> <span style=''>simple</span> <span style=''>and</span> <span style=''>analytic</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>kernels</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discovering</span> <span style=''>patterns</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performing</span> <span style=''>long</span> <span style=''>range</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extrapolation</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>synthetic</span> <span style=''>examples</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>atmospheric</span> <span style=''>CO2</span> <span style=''>trends</span> <span style=''>and</span> <span style=''>airline</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>passenger</span> <span style=''>data</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Mini</span> <span style=''>Batch</span> <span style=''>Primal</span> <span style=''>and</span> <span style=''>Dual</span> <span style=''>Methods</span> <span style=''>for</span> <span style=''>SVMs</span> <br/><br/><span style=''>We</span> <span style=''>address</span> <span style=''>the</span> <span style=''>issue</span> <span style=''>of</span> <span style=''>using</span> <span style=''>mini</span> <span style=''>batches</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>of</span> <span style=''>SVMs</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>same</span> <span style=''>quantity</span> <span style=''>the</span> <span style=''>spectral</span> <span style=''>norm</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>controls</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parallelization</span> <span style=''>speedup</span> <span style=''>obtained</span> <span style=''>for</span> <span style=''>both</span> <span style=''>primal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>subgradient</span> <span style=''>descent</span> <span style=''>(SGD)</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>stochastic</span> <span style=''>dual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coordinate</span> <span style=''>ascent</span> <span style=''>(SCDA)</span> <span style=''>methods</span> <span style=''>and</span> <span style=''>use</span> <span style=''>it</span> <span style=''>to</span> <span style=''>derive</span> <span style=''>novel</span> <span style=''>variants</span> <span style=''>of</span> <span style=''>mini</span> <span style=''>batched</span> <span style=''>SDCA</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.30386740331491713);'>guarantees</span> <span style=''>for</span> <span style=''>both</span> <span style=''>methods</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expressed</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>the</span> <span style=''>original</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>nonsmooth</span> <span style=''>primal</span> <span style=''>problem</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>hinge</span> <span style=''>loss</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>How</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>initialization</span> <span style=''>affects</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stability</span> <span style=''>of</span> <span style=''>the</span> <span style=''>k</span> <span style=''>means</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigate</span> <span style=''>the</span> <span style=''>role</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>initialization</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stability</span> <span style=''>of</span> <span style=''>the</span> <span style=''>k</span> <span style=''>means</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>As</span> <span style=''>opposed</span> <span style=''>to</span> <span style=''>other</span> <span style=''>papers</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>actual</span> <span style=''>k</span> <span style=''>means</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style=''>do</span> <span style=''>not</span> <span style=''>ignore</span> <span style=''>its</span> <span style=''>property</span> <span style=''>of</span> <span style=''>getting</span> <span style=''>stuck</span> <span style=''>in</span> <span style=''>local</span> <span style=''>optima</span> <span style=''>We</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interested</span> <span style=''>in</span> <span style=''>the</span> <span style=''>actual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>not</span> <span style=''>only</span> <span style=''>in</span> <span style=''>the</span> <span style=''>costs</span> <span style=''>of</span> <span style=''>the</span> <span style=''>solution</span> <span style=''>We</span> <span style=''>analyze</span> <span style=''>when</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>initializations</span> <span style=''>lead</span> <span style=''>to</span> <span style=''>the</span> <span style=''>same</span> <span style=''>local</span> <span style=''>optimum</span> <span style=''>and</span> <span style=''>when</span> <span style=''>they</span> <span style=''>lead</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>local</span> <span style=''>optima</span> <span style=''>This</span> <span style=''>enables</span> <span style=''>us</span> <span style=''>to</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reasonable</span> <span style=''>to</span> <span style=''>select</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>clusters</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stability</span> <span style=''>scores</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08374910905203137)
# 	experimental (0.13257305773342837)
# 	processing (0.1097647897362794)
# 	representation (0.13506771204561654)
# 	segmentation (0.07305773342836779)
# 	information (0.24483250178189594)
# 	different (0.2626514611546686)
# 	detection (0.13292943692088383)
# 	recognition (0.1286528866714184)
# 	convolutional (0.14611546685673557)
#
# Some Statistics words are:
# 	stochastic (0.13189568706118354)
# 	variables (0.13891675025075226)
# 	estimation (0.17452357071213642)
# 	statistical (0.15947843530591777)
# 	theoretical (0.15496489468405217)
# 	distribution (0.18204613841524575)
# 	algorithm (0.39969909729187564)
# 	dimensional (0.1900702106318957)
# 	inference (0.20361083249749248)
# 	regression (0.18706118355065196)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b8d0cc59-139c-4d05-94a2-99254c632b00" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8d0cc59-139c-4d05-94a2-99254c632b00")) {                    Plotly.newPlot(                        "b8d0cc59-139c-4d05-94a2-99254c632b00",                        [{"x":["simplicity","describes","performance","balancing","granulation","information","stability","combining","iteration","algorithm","inference","guaranteed","validation","organizing","application","conversion","processing","reference","compensated","respectively","compression","affecting","therefore","estimations","constructions","techniques","separable","procedures","dependency","estimation","comparing","applications","compensation","interpolation","experimental","prediction","predicted","diversity","examination","theoretic","foundation","beneficial","specifications","autocorrelation","specifically","calculated","considers","algorithms","theoretically","translational","available","comprehensive","cumulative","literature","bernoulli","accompanied","asymptotically","experiments","positively","comparison","providing","stochastic","asymptotic","numerical","optimality","reproducing","interaction","selection","involving","assumption","dimension","advantage","computation","established","predictor","different","computational","properties","regression","thresholding","dimensional","modification","simulated","including","theoretical","desirable","guarantee","effectiveness","conditions","functions","computing","developed","supported","currently","sophisticated","presented","counterparts","principles","incomplete","complexity","observations","variational","simultaneously","dictionary","recursively","underlying","sequentially","exploiting","outperforms","extracting","streaming","hierarchical","objective","commonplace","conducted","explicitly","envisaged","approximate","framework","parameters","obtaining","illustrate","arbitrary","processes","practical","estimator","introduction","demonstrate","clustering","likelihood","blockwise","probabilistic","constructing","classification","constructed","estimating","components","generating","estimators","justification","derivation","criterion","consistent","surrogate","imbalance","sensitive","maximizing","consistently","detection","suspicious","perception","minimizing","perspective","monitoring","supervised","benchmarked","important","conclusion","applicability","equivalent","extensive","potential","competitive","occurring","limitation","representing","foreground","occlusion","synthetic","frequently","distinctive","generation","especially","background","accurately","carefully","interactions","conventional","boundaries","reflecting","variations","characteristics","deblurring","assessment","inspection","databases","combinations","identification","determine","component","potentially","consisting","vulnerability","conceptually","automation","automated","configuration","penetration","strategies","weaknesses","understanding","mitigation","investigate","inconsistent","knowledge","inconsistency","constraint","description","meaningful","semantics","conclusions","increasing","advantages","entailment","paraconsistent","monotonic","assertions","reasoning","promising","persistent","isometric","invariant","variability","indicating","mathematically","embedding","development","representations","embeddings","pertinence","traditional","sentiment","algebraic","principled","relationships","neuroscience","difficult","distributions","threshold","bootstrapped","production","favorably","refitting","incorporated","parsimonious","investigations","optimization","responses","understand","combination","minimally","structure","recordings","contributing","interpret","regulariz ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	refitting
# 	emphsparse
# 	framelets
# 	matchings
# 	irregularly
# 	metabolites
# 	disregarding
# 	zebrafish
# 	frontiers
# 	necessitate
# 	inordinately
# 	confounder
# 	eigenspaces
# 	changepoint
# 	fluorescence
# 	activates
# 	accompanies
# 	emphstructured
# 	projectorg
# 	interpolating
# Some words which never appear in Statistics papers:
# 	granulation
# 	specifications
# 	benchmarked
# 	deblurring
# 	paraconsistent
# 	pertinence
# 	phenotypic
# 	navigation
# 	volumetric
# 	volunteers
# 	ontological
# 	publishing
# 	adaptability
# 	thumbnail
# 	empowered
# 	conversational
# 	transposed
# 	upsamples
# 	inheritance
# 	radioactive

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0615681351988485e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7633333333333333
